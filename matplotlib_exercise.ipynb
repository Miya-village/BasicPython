# %% [markdown]
# # 【確認課題】Matplotlib

# %%
# 使うライブラリ
# !pip install japanize-matplotlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import japanize_matplotlib
japanize_matplotlib.japanize()

import seaborn as sns

# %% [markdown]
# ## 1問目
# 使うcsvはhist_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問1](./imgs/matplotlib/plot_1.png)

# %%
df1 = pd.read_csv("data/hist_data.csv")

# %%
plt.hist(df1["aデータ"], bins = 30, alpha = 0.5, label = "aデータ")
plt.hist(df1["bデータ"], bins = 30, alpha = 0.5, label = "bデータ")

plt.legend(loc = "upper right")

plt.xlabel("温度(℃)")
plt.ylabel("度数")
# Out:
# Text(0, 0.5, '度数')

# %% [markdown]
# ## 2問目
# 使うcsvはscatter_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問2](./imgs/matplotlib/plot_2.png)

# %%
df2 = pd.read_csv("data/scatter_data.csv")
df2["class"] = df2["class"].replace({0:"class0", 1:"class1", 2:"class2"})

# %%
sns.scatterplot(data = df2, x = "length (cm)", y = "width (cm)", hue = "class", palette="bright")

plt.title("クラス０〜２のlengthとwidthに関する散布図")
plt.xlabel("length(cm)")
plt.ylabel("width(cm)")

plt.grid(True)

# %% [markdown]
# ## 3問目
# 使うcsvはline_data.csvです。下に2つの画像を表示するコードを書いてください。

# %% [markdown]
# ![問3_1](./imgs/matplotlib/plot_3_1.png)

# %% [markdown]
# ![問3_2](./imgs/matplotlib/plot_3_2.png)

# %%
df3 = pd.read_csv("data/line_data.csv")

# %%
plt.plot(df3["期間"], df3["件数"], marker = "o")

plt.xlabel("期間")
plt.ylabel("件数")

plt.grid(True)

plt.xticks(rotation = 30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.bar(df3["期間"], df3["費用"])

plt.xlabel("期間")
plt.ylabel("費用")

plt.grid(True)

plt.xticks(rotation = 30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
